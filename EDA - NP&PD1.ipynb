# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv(r'C:\Users\de\JYP\ALL_CSV\weather.csv')
data
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %% [markdown]
# ## Some of the operations in the CSV

# %%
data['WindGustDir'].unique()
# Out:
# array(['NW', 'ENE', 'SSE', 'SE', 'E', 'S', 'N', 'WNW', 'ESE', 'NE', 'NNE',
#        'NNW', 'SW', 'W', 'WSW', 'SSW', nan], dtype=object)

# %%
data.nunique()
# Out:
# MinTemp          180
# MaxTemp          187
# Rainfall          47
# Evaporation       55
# Sunshine         114
# WindGustDir       16
# WindGustSpeed     35
# WindDir9am        16
# WindDir3pm        16
# WindSpeed9am      22
# WindSpeed3pm      26
# Humidity9am       60
# Humidity3pm       74
# Pressure9am      190
# Pressure3pm      193
# Cloud9am           9
# Cloud3pm           9
# Temp9am          178
# Temp3pm          200
# RainToday          2
# RISK_MM           47
# RainTomorrow       2
# dtype: int64

# %%
data['RainTomorrow'].value_counts()
# Out:
# RainTomorrow
# No     300
# Yes     66
# Name: count, dtype: int64

# %% [markdown]
# ## Count the speed of the wind?

# %%
data['WindGustSpeed'].unique()
# Out:
# array([30., 39., 85., 54., 50., 44., 43., 41., 48., 31., 46., 52., 33.,
#        59., 26., 28., 35., 22., 76., 65., 57., 69., 61., 24., 83., 63.,
#        17., 20., nan, 15., 13., 70., 78., 67., 98., 80.])

# %%
data['WindGustSpeed'].nunique()
# Out:
# 35

# %% [markdown]
# ## Number of times when it is rain tommorrow?

# %%
data[data.RainTomorrow == 'Yes']
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 8        8.8     19.5       0.0          4.0       4.1           S
# ..       ...      ...       ...          ...       ...         ...
# 326      3.2     21.9       0.0          6.8       5.2          NW
# 337     16.8     28.9       0.0         10.0      10.8         NNW
# 338     14.4     20.7       7.6          9.4       4.9         NNW
# 340     11.2     18.0       0.0          4.8       8.4           W
# 347      6.7     26.1       0.0          6.2       7.5         SSW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
data.groupby('RainTomorrow').get_group('No')
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# 5        6.2     16.9       0.0          5.8       8.2          SE
# 6        6.1     18.2       0.2          4.2       8.4          SE
# 7        8.3     17.0       0.0          5.6       4.6           E
# 9        8.4     22.8      16.2          5.4       7.7           E
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 4             50.0        SSE        ESE          20.0  ...           49
# ...

# %% [markdown]
# ## Wind speed calculating for 30 ?

# %%
data[data.WindGustSpeed == 30]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 10       9.1     25.2       0.0          4.2      11.9           N
# 12      10.1     27.9       0.0          7.2      13.0         WNW
# 29      13.6     24.1       0.4          2.6       0.5         NNW
# 49      12.6     23.1       3.4          1.6       2.3         NNW
# 58      14.4     31.6       0.0          6.6      13.6         NNW
# 92      16.0     23.8       2.2          5.4       6.2         SSE
# 93      14.9     28.8       0.0          5.8       8.1         NNE
# 96      16.8     22.8       9.0          2.8       0.3         ESE
# 104     12.6     18.2      11.0          3.2       0.4         ENE
# 141     13.0     14.8       0.0          8.2       0.0          SE
# 143     12.8     24.9       0.0          2.4       6.2         ENE
# 172      2.4     20.6       0.0          2.8      10.1           E
# ...

# %% [markdown]
# ## Finding null values

# %%
data.isnull().sum()
# Out:
# MinTemp           0
# MaxTemp           0
# Rainfall          0
# Evaporation       0
# Sunshine          3
# WindGustDir       3
# WindGustSpeed     2
# WindDir9am       31
# WindDir3pm        1
# WindSpeed9am      7
# WindSpeed3pm      0
# Humidity9am       0
# Humidity3pm       0
# Pressure9am       0
# Pressure3pm       0
# Cloud9am          0
# Cloud3pm          0
# Temp9am           0
# Temp3pm           0
# RainToday         0
# RISK_MM           0
# RainTomorrow      0
# dtype: int64

# %% [markdown]
# ## Renaming a column

# %%
data.rename(columns={'RISK_MM':'Risk(mm)'} , inplace=False)
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %% [markdown]
# ## Mean of 'cloudat9am'

# %%
data['Cloud9am'].mean()
# Out:
# 3.890710382513661

# %%
data.Cloud9am.mean()
# Out:
# 3.890710382513661

# %% [markdown]
# ## std of Humidity9am

# %%
data.Humidity9am.std()
# Out:
# 13.137058140203433

# %% [markdown]
# ## All the vlues when 'rainfall' was recorded

# %%
data.Rainfall.value_counts()
# Out:
# Rainfall
# 0.0     263
# 0.2      17
# 0.6       6
# 0.8       5
# 0.4       5
# 1.0       4
# 6.6       3
# 1.8       3
# 5.2       3
# 4.8       3
# 2.0       3
# 4.0       3
# 3.4       3
# 1.2       3
# 3.6       2
# 3.8       2
# 1.4       2
# 3.0       2
# 6.4       2
# 11.0      2
# 17.4      2
# 1.6       2
# 16.2      2
# 2.6       1
# 8.2       1
# 7.2       1
# 7.6       1
# 19.2      1
# 6.2       1
# 9.8       1
# 7.4       1
# 16.8      1
# 19.8      1
# 18.8      1
# 10.4      1
# 4.4       1
# 9.0       1
# 2.2       1
# 12.2      1
# 14.4      1
# 5.4       1
# 4.2       1
# 22.6      1
# 25.8      1
# 2.8       1
# 39.8      1
# 13.2      1
# Name: count, dtype: int64

# %% [markdown]
# ## Data containing Rainfall as 11

# %%
data[data.Rainfall == 11]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 51      19.9     22.0      11.0          4.4       5.9         NNW
# 104     12.6     18.2      11.0          3.2       0.4         ENE
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 51            76.0          N        WNW          41.0  ...           62
# 104           30.0        SSE        SSE          13.0  ...           73
#
#      Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 51         996.5        996.8         8         3     20.6     19.6
# 104       1010.0       1011.0         7         8     16.3     16.8
#
#      RainToday  RISK_MM RainTomorrow
# 51         Yes     17.4          Yes
# 104        Yes      0.2           No
#
# [2 rows x 22 columns]

# %%
data['Rainfall'] = data['Rainfall'].astype(str)
Rainfall_11 = data[data['Rainfall'].str.contains('11')]s
print(Rainfall_11.head(10))
# Out:
#      MinTemp  MaxTemp Rainfall  Evaporation  Sunshine WindGustDir  \
# 51      19.9     22.0     11.0          4.4       5.9         NNW
# 104     12.6     18.2     11.0          3.2       0.4         ENE
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 51            76.0          N        WNW          41.0  ...           62
# 104           30.0        SSE        SSE          13.0  ...           73
#
#      Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 51         996.5        996.8         8         3     20.6     19.6
# 104       1010.0       1011.0         7         8     16.3     16.8
#
#      RainToday  RISK_MM RainTomorrow
# 51         Yes     17.4          Yes
# 104        Yes      0.2           No
#
# [2 rows x 22 columns]

# %% [markdown]
# ## Data Containing WindGustDir as NE

# %%
data['WindGustDir'] = data['WindGustDir'].astype(str)
WindGustDir_NE = data[data['WindGustDir'].str.contains('NE')] 
print(WindGustDir_NE)
# Out:
#      MinTemp  MaxTemp Rainfall  Evaporation  Sunshine WindGustDir  \
# 1       14.0     26.9      3.6          4.4       9.7         ENE
# 19      15.6     33.4      0.0          8.0      10.4          NE
# 23      12.0     24.3      0.4          1.2       7.5         NNE
# 24      15.4     28.4      0.0          4.4       8.1         ENE
# 26      13.3     22.2      0.2          6.6       2.3         ENE
# 31      11.6     26.3      4.2          1.6      12.0         NNE
# 34      14.5     21.8      0.0          8.4       9.8         ENE
# 35      16.3     26.8      0.0          6.0       6.3         ENE
# 37      16.5     28.2      4.0          4.2       8.8          NE
# 40      11.8     18.5      0.6          4.8       2.3         ENE
# 41      11.7     21.5      0.0          4.2       7.3         ENE
# 47       7.5     20.9      0.0          6.6       8.7         ENE
# 48      12.8     21.0      0.0          6.4       0.8          NE
# ...

# %% [markdown]
# ## Speed is 30 and Rainfall is 0.0

# %%
data[(data['WindGustSpeed']> 30) & (data['Rainfall'] == 0.0)]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 5        6.2     16.9       0.0          5.8       8.2          SE
# 7        8.3     17.0       0.0          5.6       4.6           E
# 8        8.8     19.5       0.0          4.0       4.1           S
# 13      12.1     30.9       0.0          6.2      12.4          NW
# 14      10.1     31.2       0.0          8.8      13.1          NW
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 5             44.0         SE          E          20.0  ...           57
# ...

# %% [markdown]
# ## sum/count value of Evaporation against the each column .

# %%
data.groupby('Evaporation').count()
# Out:
#              MinTemp  MaxTemp  Rainfall  Sunshine  WindGustDir  WindGustSpeed  \
# Evaporation
# 0.2                2        2         2         2            2              2
# 0.6                5        5         5         5            5              5
# 0.8                4        4         4         4            4              4
# 1.0                3        3         3         3            3              3
# 1.2                8        8         8         7            8              8
# 1.4               15       15        15        15           15             15
# 1.6               13       13        13        13           13             13
# 1.8               14       14        14        14           13             13
# 2.0               10       10        10        10            9              9
# 2.2               21       21        21        21           20             21
# 2.4               11       11        11        11           11             11
# ...

# %%
data.groupby('Evaporation').sum()
# Out:
#              MinTemp  MaxTemp  Rainfall  Sunshine  \
# Evaporation
# 0.2             20.8     30.1       8.6       3.1
# 0.6             23.1     70.0       5.6      15.6
# 0.8             -1.2     44.0       2.0      25.2
# 1.0              5.5     42.2       0.0       6.2
# 1.2             32.3    134.0       6.0      57.1
# 1.4             25.8    195.4      33.2      98.0
# 1.6             48.7    215.2      12.4      96.7
# 1.8             21.7    188.0      27.0      72.1
# 2.0             31.2    167.4       4.0      62.0
# 2.2             44.1    325.3      18.4     142.1
# 2.4             24.5    180.4      24.0      71.4
# 2.6             49.5    216.0      28.6     103.2
# 2.8            124.4    348.7      44.2     118.7
# 3.0              9.2    115.7       1.8      42.7
# 3.2             57.6    141.4      20.2      53.5
# 3.4             48.0    212.3       0.6     110.2
# 3.6             22.6     97.4       2.0      43.1
# ...

# %% [markdown]
# ### WindGustDir is NE

# %%
data[data.WindGustDir=='NE']
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 19      15.6     33.4       0.0          8.0      10.4          NE
# 37      16.5     28.2       4.0          4.2       8.8          NE
# 48      12.8     21.0       0.0          6.4       0.8          NE
# 60      13.8     33.5       0.0         11.4      13.6          NE
# 65      12.1     27.5       0.0          7.4      11.7          NE
# 70      14.7     34.2       0.0          6.6      12.8          NE
# 79      15.3     19.6      18.8          5.0       0.0          NE
# 83       9.9     24.4       0.0          5.8      10.8          NE
# 102      8.9     26.0       0.0          5.0      10.7          NE
# 110     11.4     27.1       0.0          5.6      12.1          NE
# 136     11.3     32.3       0.0          9.4      11.4          NE
# 137     11.7     30.2       0.0          7.8      11.2          NE
# 139     15.1     26.2       0.0          9.0       9.8          NE
# ...

# %% [markdown]
# ## Speed is 30 OR Rainfall is 0.0

# %%
data[(data['WindGustSpeed']==30) | (data['Rainfall']==0.0)]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 5        6.2     16.9       0.0          5.8       8.2          SE
# 7        8.3     17.0       0.0          5.6       4.6           E
# 8        8.8     19.5       0.0          4.0       4.1           S
# 10       9.1     25.2       0.0          4.2      11.9           N
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %% [markdown]
# ## When wind speed is 30 and rainfall is 0  OR 'WindGustDir' is "S"

# %%
data[(data['WindGustSpeed']==30) & (data['Rainfall']==0) | (data['WindGustDir']=='S')]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 8        8.8     19.5       0.0          4.0       4.1           S
# 10       9.1     25.2       0.0          4.2      11.9           N
# 12      10.1     27.9       0.0          7.2      13.0         WNW
# 17      11.7     30.0       1.2          7.2      10.1           S
# 27      12.9     28.0       0.0          4.4      10.7           S
# 45      15.5     21.1       5.4          6.4       0.9           S
# 58      14.4     31.6       0.0          6.6      13.6         NNW
# 93      14.9     28.8       0.0          5.8       8.1         NNE
# 112     16.3     24.8       1.8          7.8       3.8           S
# 120      7.7     18.4      10.4          5.2      12.0           S
# 121      4.4     21.8       0.0          6.2      12.1           S
# 141     13.0     14.8       0.0          8.2       0.0          SE
# ...
